# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\nobod\OneDrive\Data Science_2025\Datafiles\Visadataset - Visadataset (1).csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
print("categorical columns:",cat)
num=visa_df.select_dtypes(exclude='object').columns
print("numerical columns:",num)
# Out:
# categorical columns: Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')
# numerical columns: Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
wage_data=visa_df['prevailing_wage']
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
wage_data.mean()
# Out:
# 74455.81459209183

# %%
mean=round(np.mean(wage_data),2)
mean
# Out:
# 74455.81

# %%
count=wage_data.count()
count
# Out:
# 25480

# %%
min=wage_data.min()
min
# Out:
# 2.1367

# %%
max=wage_data.max()
max
# Out:
# 319210.27

# %%
median=round(wage_data.median(),2)
median
# Out:
# 70308.21

# %%
n_25p=np.percentile(wage_data,25)
n_25p=round(n_25p,2)
n_25p
# Out:
# 34015.48

# %%
n_50p=np.percentile(wage_data,50)
n_50p=round(n_50p,2)
n_50p
# Out:
# 70308.21

# %%
n_75p=np.percentile(wage_data,75)
n_75p=round(n_75p,2)
n_75p
# Out:
# 107735.51

# %%
max_value=round(wage_data.max(),2)
max_value
# Out:
# 319210.27

# %%
min_value=round(wage_data.min(),2)
min_value
# Out:
# 2.14

# %%
values=[mean,median,max_value,min_value,count]

pd.DataFrame(values,
            index=['MEAN','MEDIAN','MAX','MIN','COUNT'],
            columns=['prevailing wage'])
# Out:
#         prevailing wage
# MEAN           74455.81
# MEDIAN         70308.21
# MAX           319210.27
# MIN                2.14
# COUNT          25480.00
